# %%
import sys
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
FILE_NAME='LOSSES_COMPARISON/ghana_late_versions'
step=15



f1='MODEL_GHANA_GD_NODILATED_NEW_SAVE/TEST_SAVE/' 
f2='MODEL_GHANA_DNV1_NEW_SAVE/TEST_SAVE/'
f3='MODEL_GHANA_VAL_2_ORIG_NEW_SAVE/TEST_SAVE/'
f4='MODEL_GHANA_RUDV1_NEW_SAVE/TEST_SAVE/'
f5='MODEL_GHANA_RUDV2_NEW_SAVE/TEST_SAVE/'
# f6='MODEL_GHANA_V8_NEW_SAVE/TEST_SAVE/'

leg=['RUBV5','DNV1','RUBV3','RUDV1','RUDV2']
#TRAIN
fig1 = plt.figure()
ax1=plt.subplot(111)

with open(f1+'avg_loss_train.txt', "r",) as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
            
t1=np.asarray(t1)
ite1 = np.arange(0,len(t1),1)


with open(f2+'avg_loss_train.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line))
t2=np.asarray(t2)
ite2 = np.arange(0,len(t2),1)

with open(f3+'avg_loss_train.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))
        

t3=np.asarray(t3)
ite3 = np.arange(0,len(t3),1)

with open(f4+'avg_loss_train.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(0,len(t4),1)

with open(f5+'avg_loss_train.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(0,len(t5),1)

# with open(f6+'avg_loss_train.txt', "r") as ins:
#     t6 = []
#     for line in ins.readlines():
#         t6.append(float(line))
# t6=np.asarray(t6)
# ite6 = np.arange(0,len(t6),1)



# ax1.set_ylim(0.04,0.06)
ax1.plot(ite1,t1,'b', label=leg[0])
ax1.plot(ite2,t2,'g', label=leg[1])
ax1.plot(ite3,t3,'r', label=leg[2])
ax1.plot(ite4,t4,'y', label=leg[3])
ax1.plot(ite5,t5,'m', label=leg[4])
# ax1.plot(ite6,t6,'k', label=leg[5])
plt.title('TRAINING')
plt.ylabel('LOSS')
plt.xlabel('iterations')
ax1.legend(loc='upper right',fontsize='small') 
plt.show()
fig1.savefig(FILE_NAME+'_train_loss.png')


#TEST
fig2 = plt.figure()
ax2=plt.subplot(111)

with open(f1+'loss_verif.txt', "r") as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
t1=np.asarray(t1)
ite1 = np.arange(0,len(t1),1)
print(leg[0])
print("Minimum verif loss :%.4f, Model number %d"%(np.amin(t1),np.argmin(t1)))



with open(f2+'loss_verif.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line)) 
t2=np.asarray(t2)
ite2 = np.arange(0,len(t2),1)

print(leg[1])
print("Minimum verif loss :%.4f, Model number %d"%(np.amin(t2),np.argmin(t2)))

with open(f3+'loss_verif.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))
t3=np.asarray(t3)
ite3 = np.arange(0,len(t3),1)


print(leg[2])
print("Minimum verif loss :%.4f, Model number %d"%(np.amin(t3),np.argmin(t3)))

with open(f4+'loss_verif.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(0,len(t4),1)

print(leg[3])
print("Minimum verif loss :%.4f, Model number %d"%(np.amin(t4),np.argmin(t4)))

with open(f5+'loss_verif.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(0,len(t5),1)


print(leg[4])
print("Minimum verif loss :%.4f, Model number %d"%(np.amin(t5),np.argmin(t5)))

# with open(f6+'loss_verif.txt', "r") as ins:
#     t6 = []
#     for line in ins.readlines():
#         t6.append(float(line))
# t6=np.asarray(t6)
# ite6 = np.arange(0,len(t6),1)

# print(leg[5])
# print("Minimum verif loss :%.4f, Model number %d"%(np.amin(t6),np.argmin(t6)))

# ax2.set_ylim(0.1,0.25)
ax2.plot(ite1,t1,'b', label=leg[0])
ax2.plot(ite2,t2,'g', label=leg[1])
ax2.plot(ite3,t3,'r', label=leg[2])
ax2.plot(ite4,t4,'y', label=leg[3])
ax2.plot(ite5,t5,'m', label=leg[4])
# ax2.plot(ite6,t6,'k', label=leg[5])
plt.title('VERIFICATION')
plt.ylabel('LOSS')
plt.xlabel('epochs')
ax2.legend(loc='upper right',fontsize='small') 
plt.show()
fig2.savefig(FILE_NAME+'_verif_loss.png')



fig3 = plt.figure()
ax3=plt.subplot(111)

with open(f1+'error_verif.txt', "r") as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
t1=np.asarray(t1)
ite1 = np.arange(0,len(t1),1)

print(leg[0])
print("Minimum error rate:%.4f, Model number %d"%(np.amin(t1),np.argmin(t1)))

with open(f2+'error_verif.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line))
t2=np.asarray(t2)
ite2 = np.arange(0,len(t2),1)

print(leg[1])
print("Minimum error rate:%.4f, Model number %d"%(np.amin(t2),np.argmin(t2)))

with open(f3+'error_verif.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))

t3=np.asarray(t3)
ite3 = np.arange(0,len(t3),1)

print(leg[2])
print("Minimum error rate:%.4f, Model number %d"%(np.amin(t3),np.argmin(t3)))

with open(f4+'error_verif.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(0,len(t4),1)
print(leg[3])
print("Minimum error rate:%.4f, Model number %d"%(np.amin(t4),np.argmin(t4)))

with open(f5+'error_verif.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(0,len(t5),1)
print(leg[4])
print("Minimum error rate:%.4f, Model number %d"%(np.amin(t5),np.argmin(t5)))
    

# with open(f6+'error_verif.txt', "r") as ins:
#     t6 = []
#     for line in ins.readlines():
#         t6.append(float(line))
# t6=np.asarray(t6)
# ite6 = np.arange(0,len(t6),1)

# print(leg[5])
# print("Minimum error rate :%.4f, Model number %d"%(np.amin(t6),np.argmin(t6)))

ax3.plot(ite1,t1,'b', label=leg[0])  
ax3.plot(ite2,t2,'g', label=leg[1])
ax3.plot(ite3,t3,'r', label=leg[2])
ax3.plot(ite4,t4,'y', label=leg[3])
ax3.plot(ite5,t5,'m', label=leg[4])
# ax3.plot(ite6,t6,'k', label=leg[5])
plt.title('VERIFICATION')
plt.ylabel('Error rate')
plt.xlabel('epochs')
ax3.legend(loc='upper right',fontsize='small') 
plt.show()   
fig3.savefig(FILE_NAME+'_verif_error.png')   


fig5 = plt.figure()
ax5=plt.subplot(111)

with open(f1+'iou_acc_verif.txt', "r") as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
    
t1=np.asarray(t1)
ite1 = np.arange(step,(len(t1)+1)*step,step)


with open(f2+'iou_acc_verif.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line))
t2=np.asarray(t2)
ite2 = np.arange(step,(len(t2)+1)*step,step)

      
with open(f3+'iou_acc_verif.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))

t3=np.asarray(t3)
ite3 = np.arange(step,(len(t3)+1)*step,step)

      
with open(f4+'iou_acc_verif.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(step,(len(t4)+1)*step,step)

with open(f5+'iou_acc_verif.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(step,(len(t5)+1)*step,step)

# with open(f6+'iou_acc_verif.txt', "r") as ins:
#     t6 = []
#     for line in ins.readlines():
#         t6.append(float(line))
# t6=np.asarray(t6)
# ite6 = np.arange(step,(len(t6)+1)*step,step)


ax5.plot(ite1,t1,'b', label=leg[0])  
ax5.plot(ite2,t2,'g', label=leg[1])
ax5.plot(ite3,t3,'r', label=leg[2])
ax5.plot(ite4,t4,'y', label=leg[3])
ax5.plot(ite5,t5,'m', label=leg[4])
# ax5.plot(ite6,t6,'k', label=leg[5])
plt.title('VERIFICATION')
plt.ylabel('Precision IOU')
plt.xlabel('epochs')
ax5.legend(loc='lower right',fontsize='small') 
plt.show()   
fig5.savefig(FILE_NAME+'_verif_acc_iou.png')   


fig4 = plt.figure()
ax4=plt.subplot(111)


with open(f1+'f1_iou_verif.txt', "r") as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
t1=np.asarray(t1)
ite1 = np.arange(step,(len(t1)+1)*step,step)

with open(f2+'f1_iou_verif.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line))
t2=np.asarray(t2)
ite2 = np.arange(step,(len(t2)+1)*step,step)

with open(f3+'f1_iou_verif.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))

t3=np.asarray(t3)
ite3 = np.arange(step,(len(t3)+1)*step,step)

with open(f4+'f1_iou_verif.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(step,(len(t4)+1)*step,step)

with open(f5+'f1_iou_verif.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(step,(len(t5)+1)*step,step)

# with open(f6+'f1_iou_verif.txt', "r") as ins:
#     t6 = []
#     for line in ins.readlines():
#         t6.append(float(line))
# t6=np.asarray(t6)
# ite6 = np.arange(step,(len(t6)+1)*step,step)

ax4.plot(ite1,t1,'b', label=leg[0])  
ax4.plot(ite2,t2,'g', label=leg[1]) 
ax4.plot(ite3,t3,'r', label=leg[2])
ax4.plot(ite4,t4,'y', label=leg[3])
ax4.plot(ite5,t5,'m', label=leg[4])
# ax4.plot(ite6,t6,'k', label=leg[5])
plt.title('VERIFICATION')
plt.ylabel('f1 IOU')
plt.xlabel('epochs')
ax4.legend(loc='lower right',fontsize='small') 
plt.show()
fig4.savefig(FILE_NAME+'_f1_verif_iou.png')
# Out:
# RUBV5
# Minimum verif loss :0.0141, Model number 38
# DNV1
# Minimum verif loss :0.0150, Model number 50
# RUBV3
# Minimum verif loss :0.0138, Model number 39
# RUDV1
# Minimum verif loss :0.0160, Model number 32
# RUDV2
# Minimum verif loss :0.0154, Model number 37
# RUBV5
# Minimum error rate:0.5204, Model number 41
# DNV1
# Minimum error rate:0.5277, Model number 50
# RUBV3
# Minimum error rate:0.5176, Model number 58
# RUDV1
# Minimum error rate:0.5471, Model number 50
# RUDV2
# Minimum error rate:0.5265, Model number 37

# %% [markdown]
#  !gpustat
