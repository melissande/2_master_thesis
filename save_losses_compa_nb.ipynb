# %%
import sys
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
FILE_NAME='LOSSES_COMPARISON/spacenet_dist5_no_dist5_v2_dilated'
# FILE_NAME='LOSSES_COMPARISON/ghana_dist5_tf_aug_no_dist5_tf_noaug'
# FILE_NAME='LOSSES_COMPARISON/ghana_dist5_no_dist5_no_aug'

step=15



f1='MODEL_SPACENET_DIST5/TEST_SAVE/'
f2='MODEL_SPACENET_NODIST5/TEST_SAVE/'
f3='MODEL_SPACENET_DILATED_MELI_V2/TEST_SAVE/'
f4='MODEL_SPACENET_UNET_DILATED_2_2/TEST_SAVE/'
f5='MODEL_SPACENET_DIST_v2/TEST_SAVE/'

leg=['DIST 5','NO DIST 5','DILATED MELI v2','DILATED UNET 2','DIST V2']

# f1='MODEL_GHANA_TF_AUG/TEST_SAVE/'
# f2='MODEL_GHANA_TF_NO_AUG/TEST_SAVE/'
# f3='MODEL_GHANA_TF_AUG_NODIST5/TEST_SAVE/'
# f4='MODEL_GHANA_TF_NO_AUG_NODIST5/TEST_SAVE/'


# leg=['DIST TF AUG','DIST TF NO AUG', 'NO DIST TF AUG', 'NO DIST TF NO AUG']

# f1='MODEL_GHANA_NODIST_NODATA_AUG/TEST_SAVE/'
# f2='MODEL_GHANA_TF_NO_AUG_NODIST5/TEST_SAVE/'
# f3='MODEL_GHANA_DIST_NODATA_AUG/TEST_SAVE/'
# f4='MODEL_GHANA_TF_NO_AUG/TEST_SAVE/'
# f5='MODEL_GHANA_TF_NO_AUG_DIST5_560000/TEST_SAVE/'


# leg=['NO DIST SCRATCH','NO DIST TF', 'DIST SCRACTH', 'DIST TF','DIST TF 56000']

#TRAIN
fig1 = plt.figure()
ax1=plt.subplot(111)

with open(f1+'avg_loss_train.txt', "r",) as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
            
t1=np.asarray(t1)
ite1 = np.arange(0,len(t1),1)


with open(f2+'avg_loss_train.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line))
t2=np.asarray(t2)
ite2 = np.arange(0,len(t2),1)

with open(f3+'avg_loss_train.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))
        

t3=np.asarray(t3)
ite3 = np.arange(0,len(t3),1)

with open(f4+'avg_loss_train.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(0,len(t4),1)

with open(f5+'avg_loss_train.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(0,len(t5),1)


# ax1.set_ylim(0.04,0.06)
ax1.plot(ite1,t1,'b', label=leg[0])
ax1.plot(ite2,t2,'g', label=leg[1])
ax1.plot(ite3,t3,'r', label=leg[2])
ax1.plot(ite4,t4,'y', label=leg[3])
ax1.plot(ite5,t5,'m', label=leg[4])
plt.title('TRAINING')
plt.ylabel('LOSS')
plt.xlabel('iterations')
ax1.legend(loc='upper right',fontsize='small') 
plt.show()
fig1.savefig(FILE_NAME+'_train_loss.png')


#TEST
fig2 = plt.figure()
ax2=plt.subplot(111)

with open(f1+'loss_verif.txt', "r") as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
t1=np.asarray(t1)
ite1 = np.arange(0,len(t1),1)



with open(f2+'loss_verif.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line)) 
t2=np.asarray(t2)
ite2 = np.arange(0,len(t2),1)

with open(f3+'loss_verif.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))
t3=np.asarray(t3)
ite3 = np.arange(0,len(t3),1)


with open(f4+'loss_verif.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(0,len(t4),1)

with open(f5+'loss_verif.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(0,len(t5),1)

# ax2.set_ylim(0.1,0.2)
ax2.plot(ite1,t1,'b', label=leg[0])
ax2.plot(ite2,t2,'g', label=leg[1])
ax2.plot(ite3,t3,'r', label=leg[2])
ax2.plot(ite4,t4,'y', label=leg[3])
ax2.plot(ite5,t5,'m', label=leg[4])
plt.title('VERIFICATION')
plt.ylabel('LOSS')
plt.xlabel('epochs')
ax2.legend(loc='upper right',fontsize='small') 
plt.show()
fig2.savefig(FILE_NAME+'_verif_loss.png')



fig3 = plt.figure()
ax3=plt.subplot(111)

with open(f1+'iou_verif.txt', "r") as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
t1=np.asarray(t1)
ite1 = np.arange(step,(len(t1)+1)*step,step)

with open(f2+'iou_verif.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line))
t2=np.asarray(t2)
ite2 = np.arange(step,(len(t2)+1)*step,step)

with open(f3+'iou_verif.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))

t3=np.asarray(t3)
ite3 = np.arange(step,(len(t3)+1)*step,step)

with open(f4+'iou_verif.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(step,(len(t4)+1)*step,step)

with open(f5+'iou_verif.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(step,(len(t5)+1)*step,step)


ax3.plot(ite1,t1,'b', label=leg[0])  
ax3.plot(ite2,t2,'g', label=leg[1])
ax3.plot(ite3,t3,'r', label=leg[2])
ax3.plot(ite4,t4,'y', label=leg[3])
ax3.plot(ite5,t5,'m', label=leg[4])
plt.title('VERIFICATION')
plt.ylabel('IOU')
plt.xlabel('epochs')
ax3.legend(loc='lower right',fontsize='small') 
plt.show()   
fig3.savefig(FILE_NAME+'_verif_iou.png')   


fig5 = plt.figure()
ax5=plt.subplot(111)

with open(f1+'iou_acc_verif.txt', "r") as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
t1=np.asarray(t1)
ite1 = np.arange(step,(len(t1)+1)*step,step)

with open(f2+'iou_acc_verif.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line))
t2=np.asarray(t2)
ite2 = np.arange(step,(len(t2)+1)*step,step)

with open(f3+'iou_acc_verif.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))

t3=np.asarray(t3)
ite3 = np.arange(step,(len(t3)+1)*step,step)

with open(f4+'iou_acc_verif.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(step,(len(t4)+1)*step,step)

with open(f5+'iou_acc_verif.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(step,(len(t5)+1)*step,step)

ax5.plot(ite1,t1,'b', label=leg[0])  
ax5.plot(ite2,t2,'g', label=leg[1])
ax5.plot(ite3,t3,'r', label=leg[2])
ax5.plot(ite4,t4,'y', label=leg[3])
ax5.plot(ite5,t5,'m', label=leg[4])
plt.title('VERIFICATION')
plt.ylabel('Precision IOU')
plt.xlabel('epochs')
ax5.legend(loc='lower right',fontsize='small') 
plt.show()   
fig5.savefig(FILE_NAME+'_verif_acc_iou.png')   


fig4 = plt.figure()
ax4=plt.subplot(111)


with open(f1+'f1_iou_verif.txt', "r") as ins:
    t1 = []
    for line in ins.readlines():
        t1.append(float(line))
t1=np.asarray(t1)
ite1 = np.arange(step,(len(t1)+1)*step,step)

with open(f2+'f1_iou_verif.txt', "r") as ins:
    t2 = []
    for line in ins.readlines():
        t2.append(float(line))
t2=np.asarray(t2)
ite2 = np.arange(step,(len(t2)+1)*step,step)

with open(f3+'f1_iou_verif.txt', "r") as ins:
    t3 = []
    for line in ins.readlines():
        t3.append(float(line))

t3=np.asarray(t3)
ite3 = np.arange(step,(len(t3)+1)*step,step)

with open(f4+'f1_iou_verif.txt', "r") as ins:
    t4 = []
    for line in ins.readlines():
        t4.append(float(line))
t4=np.asarray(t4)
ite4 = np.arange(step,(len(t4)+1)*step,step)

with open(f5+'f1_iou_verif.txt', "r") as ins:
    t5 = []
    for line in ins.readlines():
        t5.append(float(line))
t5=np.asarray(t5)
ite5 = np.arange(step,(len(t5)+1)*step,step)


ax4.plot(ite1,t1,'b', label=leg[0])  
ax4.plot(ite2,t2,'g', label=leg[1]) 
ax4.plot(ite3,t3,'r', label=leg[2])
ax4.plot(ite4,t4,'y', label=leg[3])
ax4.plot(ite5,t5,'m', label=leg[4])
plt.title('VERIFICATION')
plt.ylabel('f1 IOU')
plt.xlabel('epochs')
ax4.legend(loc='lower right',fontsize='small') 
plt.show()
fig4.savefig(FILE_NAME+'_f1_verif_iou.png')

# %%
# !gpustat
# Out:
# coeus  Fri May 11 16:00:46 2018
# [0] TITAN X (Pascal) | 46'C,   0 % |   509 / 12189 MB | rahvi(499M)
# [1] TITAN X (Pascal) | 60'C,  45 % |  6383 / 12189 MB | s132314(6373M)
# [2] TITAN X (Pascal) | 84'C,  79 % | 11963 / 12189 MB | s162876(11949M)
# [3] TITAN X (Pascal) | 33'C,   0 % |  3602 / 12189 MB | s161362(3173M) s161362(419M)
# [4] TITAN X (Pascal) | 52'C,  39 % |  5829 / 12189 MB | s161362(5819M)
# [5] TITAN X (Pascal) | 50'C,  17 % |  3213 / 12189 MB | s161362(3203M)
# [6] TITAN X (Pascal) | 70'C,  41 % | 11755 / 12189 MB | maxvo(11745M)
# [7] TITAN X (Pascal) | 35'C,   2 % |     0 / 12189 MB |
